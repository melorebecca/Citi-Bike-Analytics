# %%
import csv 
import pandas as pd

# %%
df4 = pd.read_csv('2021_data/202104-citibike-tripdata.csv')
df4.head()
# Out:
# /Users/rebeccamelo/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ride_id rideable_type           started_at             ended_at  \
# 0  7099F9531C9DA16D   docked_bike  2021-04-28 17:27:24  2021-04-28 17:34:31
# 1  EDC6F1B1A69A7863   docked_bike  2021-04-27 17:28:02  2021-04-27 17:33:07
# 2  431A76830E10408A   docked_bike  2021-04-28 18:05:19  2021-04-28 18:10:48
# 3  C00248A0ADC009FA   docked_bike  2021-04-20 21:35:47  2021-04-20 21:56:31
# 4  BE78810D746EE516   docked_bike  2021-04-30 00:34:54  2021-04-30 01:03:29
#
#         start_station_name start_station_id          end_station_name  \
# 0  DeKalb Ave & Hudson Ave          4513.06       Douglass St & 4 Ave
# 1       E 47 St & Park Ave          6584.12           W 52 St & 6 Ave
# ...

# %%
df4.rename(columns = {'ride_id': 'Ride ID', 'rideable_type': 'Rideable Type', 'started_at': 'Started At','ended_at': 'Ended At','start_station_name':'Start Station Name',
                      'start_station_id':'Start Station Id', 'end_station_name': 'End Station Name', 'end_station,id': 'End Station Id','start_lat':'Start Latitude',
                      'start_lng':'Start Longitude','end_lat':'End Latitude','end_lng':'End Longitude',
                      'member_casual':'Member Casual'}, inplace = True)
df4.head()
# Out:
#             Ride ID Rideable Type           Started At             Ended At  \
# 0  7099F9531C9DA16D   docked_bike  2021-04-28 17:27:24  2021-04-28 17:34:31
# 1  EDC6F1B1A69A7863   docked_bike  2021-04-27 17:28:02  2021-04-27 17:33:07
# 2  431A76830E10408A   docked_bike  2021-04-28 18:05:19  2021-04-28 18:10:48
# 3  C00248A0ADC009FA   docked_bike  2021-04-20 21:35:47  2021-04-20 21:56:31
# 4  BE78810D746EE516   docked_bike  2021-04-30 00:34:54  2021-04-30 01:03:29
#
#         Start Station Name Start Station Id          End Station Name  \
# 0  DeKalb Ave & Hudson Ave          4513.06       Douglass St & 4 Ave
# 1       E 47 St & Park Ave          6584.12           W 52 St & 6 Ave
# 2       E 47 St & Park Ave          6584.12           W 52 St & 6 Ave
# 3  Irving Ave & DeKalb Ave          4898.02  Division Ave & Hooper St
# 4         3 Ave & E 112 St          7543.15  E 115 St & Lexington Ave
#
#   end_station_id  Start Latitude  Start Longitude  End Latitude  \
# ...

# %%
df5 = pd.read_csv('2021_data/202105-citibike-tripdata.csv')
df5.head()
# Out:
# /Users/rebeccamelo/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ride_id rideable_type           started_at             ended_at  \
# 0  E12103A91226099A   docked_bike  2021-05-06 17:25:01  2021-05-06 17:45:25
# 1  26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08  2021-05-13 13:07:37
# 2  A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13  2021-05-16 08:45:47
# 3  43E79A45997B7390   docked_bike  2021-05-01 08:38:14  2021-05-01 08:54:27
# 4  8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31  2021-05-09 08:27:05
#
#    start_station_name start_station_id        end_station_name end_station_id  \
# 0  Broadway & W 60 St          6948.11         1 Ave & E 78 St        7020.09
# ...

# %%
df5.rename(columns = {'ride_id': 'Ride ID', 'rideable_type': 'Rideable Type', 'started_at': 'Started At','ended_at': 'Ended At','start_station_name':'Start Station Name',
                      'start_station_id':'Start Station Id', 'end_station_name': 'End Station Name', 'end_station,id': 'End Station Id','start_lat':'Start Latitude',
                      'start_lng':'Start Longitude','end_lat':'End Latitude','end_lng':'End Longitude',
                      'member_casual':'Member Casual'}, inplace = True)
df5.head()
# Out:
#             Ride ID Rideable Type           Started At             Ended At  \
# 0  E12103A91226099A   docked_bike  2021-05-06 17:25:01  2021-05-06 17:45:25
# 1  26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08  2021-05-13 13:07:37
# 2  A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13  2021-05-16 08:45:47
# 3  43E79A45997B7390   docked_bike  2021-05-01 08:38:14  2021-05-01 08:54:27
# 4  8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31  2021-05-09 08:27:05
#
#    Start Station Name Start Station Id        End Station Name end_station_id  \
# 0  Broadway & W 60 St          6948.11         1 Ave & E 78 St        7020.09
# 1  Broadway & W 25 St          6173.08       E 2 St & Avenue B        5515.02
# 2       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
# 3       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
# 4       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
#
# ...

# %%
df6 = pd.read_csv('2021_data/202106-citibike-tripdata.csv')
df6.head()
# Out:
# /Users/rebeccamelo/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ride_id rideable_type           started_at             ended_at  \
# 0  6339C86D47EC0FAB   docked_bike  2021-06-02 17:18:45  2021-06-02 17:26:17
# 1  CDE3C147775B4002   docked_bike  2021-06-04 21:01:46  2021-06-04 21:32:09
# 2  D335C3F6B412B846   docked_bike  2021-06-15 16:39:36  2021-06-15 16:55:02
# 3  8DA6810777C89735   docked_bike  2021-06-08 11:36:40  2021-06-08 11:39:41
# 4  62D9B66A3A1D9FDF   docked_bike  2021-06-18 12:48:43  2021-06-18 13:04:14
#
#       start_station_name  start_station_id       end_station_name  \
# 0        W 51 St & 6 Ave           6740.10  E 66 St & Madison Ave
# 1       W 56 St & 10 Ave           6955.01      E 9 St & Avenue C
# ...

# %%
df6.rename(columns = {'ride_id': 'Ride ID', 'rideable_type': 'Rideable Type', 'started_at': 'Started At','ended_at': 'Ended At','start_station_name':'Start Station Name',
                      'start_station_id':'Start Station Id', 'end_station_name': 'End Station Name', 'end_station,id': 'End Station Id','start_lat':'Start Latitude',
                      'start_lng':'Start Longitude','end_lat':'End Latitude','end_lng':'End Longitude',
                      'member_casual':'Member Casual'}, inplace = True)
df6.head()
# Out:
#             Ride ID Rideable Type           Started At             Ended At  \
# 0  6339C86D47EC0FAB   docked_bike  2021-06-02 17:18:45  2021-06-02 17:26:17
# 1  CDE3C147775B4002   docked_bike  2021-06-04 21:01:46  2021-06-04 21:32:09
# 2  D335C3F6B412B846   docked_bike  2021-06-15 16:39:36  2021-06-15 16:55:02
# 3  8DA6810777C89735   docked_bike  2021-06-08 11:36:40  2021-06-08 11:39:41
# 4  62D9B66A3A1D9FDF   docked_bike  2021-06-18 12:48:43  2021-06-18 13:04:14
#
#       Start Station Name  Start Station Id       End Station Name  \
# 0        W 51 St & 6 Ave           6740.10  E 66 St & Madison Ave
# 1       W 56 St & 10 Ave           6955.01      E 9 St & Avenue C
# 2  E 56 St & Madison Ave           6732.01        E 16 St & 5 Ave
# 3        E 68 St & 3 Ave           6896.16        1 Ave & E 62 St
# 4        E 48 St & 5 Ave           6626.01        W 20 St & 8 Ave
#
#   end_station_id  Start Latitude  Start Longitude  End Latitude  \
# ...

# %%
df7 = pd.read_csv('2021_data/202107-citibike-tripdata.csv')
df7.head()
# Out:
# /Users/rebeccamelo/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ride_id rideable_type           started_at             ended_at  \
# 0  247BA541A9674BF3  classic_bike  2021-07-09 16:05:36  2021-07-09 16:18:09
# 1  125C9ACA270A5E2D  classic_bike  2021-07-11 16:23:35  2021-07-11 16:29:07
# 2  2E26264BCC15BA05  classic_bike  2021-07-23 06:22:40  2021-07-23 06:36:13
# 3  A56D23A088563424  classic_bike  2021-07-05 16:08:10  2021-07-05 16:36:00
# 4  1451F4BB884C5335  classic_bike  2021-07-26 12:28:57  2021-07-26 12:30:21
#
#      start_station_name  start_station_id                    end_station_name  \
# 0       5 Ave & E 93 St           7372.10  Frederick Douglass Blvd & W 117 St
# ...

# %%
df7.rename(columns = {'ride_id': 'Ride ID', 'rideable_type': 'Rideable Type', 'started_at': 'Started At','ended_at': 'Ended At','start_station_name':'Start Station Name',
                      'start_station_id':'Start Station Id', 'end_station_name': 'End Station Name', 'end_station,id': 'End Station Id','start_lat':'Start Latitude',
                      'start_lng':'Start Longitude','end_lat':'End Latitude','end_lng':'End Longitude',
                      'member_casual':'Member Casual'}, inplace = True)
df7.head()
# Out:
#             Ride ID Rideable Type           Started At             Ended At  \
# 0  247BA541A9674BF3  classic_bike  2021-07-09 16:05:36  2021-07-09 16:18:09
# 1  125C9ACA270A5E2D  classic_bike  2021-07-11 16:23:35  2021-07-11 16:29:07
# 2  2E26264BCC15BA05  classic_bike  2021-07-23 06:22:40  2021-07-23 06:36:13
# 3  A56D23A088563424  classic_bike  2021-07-05 16:08:10  2021-07-05 16:36:00
# 4  1451F4BB884C5335  classic_bike  2021-07-26 12:28:57  2021-07-26 12:30:21
#
#      Start Station Name  Start Station Id                    End Station Name  \
# 0       5 Ave & E 93 St           7372.10  Frederick Douglass Blvd & W 117 St
# 1       5 Ave & E 93 St           7372.10                  E 88 St & Park Ave
# 2        34 St & 38 Ave           6453.02          McGuinness Blvd & Eagle St
# 3  Lenox Ave & W 111 St           7602.05                     5 Ave & E 78 St
# 4     6 Ave & Broome St           5610.09                    6 Ave & Canal St
#
# ...

# %%
df8 = pd.read_csv('2021_data/202108-citibike-tripdata.csv')
df8.head()
# Out:
# /Users/rebeccamelo/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ride_id rideable_type           started_at             ended_at  \
# 0  FB6B89D05B67EBED  classic_bike  2021-08-24 15:59:57  2021-08-24 16:42:07
# 1  E13DA3E30CEF8DFC  classic_bike  2021-08-18 13:12:01  2021-08-18 13:21:26
# 2  56617490AB8AE69C  classic_bike  2021-08-17 14:31:23  2021-08-17 14:35:34
# 3  CA908B271C7D6663  classic_bike  2021-08-11 10:00:12  2021-08-11 10:31:01
# 4  3E170CE1F4FE179D  classic_bike  2021-08-12 19:28:38  2021-08-12 19:48:50
#
#       start_station_name  start_station_id  \
# 0     Broadway & E 21 St           6098.10
# 1        E 13 St & 2 Ave           5820.08
# 2        E 95 St & 3 Ave           7365.13
# 3  Madison Ave & E 82 St           7188.13
# ...

# %%
df8.rename(columns = {'ride_id': 'Ride ID', 'rideable_type': 'Rideable Type', 'started_at': 'Started At','ended_at': 'Ended At','start_station_name':'Start Station Name',
                      'start_station_id':'Start Station Id', 'end_station_name': 'End Station Name', 'end_station,id': 'End Station Id','start_lat':'Start Latitude',
                      'start_lng':'Start Longitude','end_lat':'End Latitude','end_lng':'End Longitude',
                      'member_casual':'Member Casual'}, inplace = True)
df8.head()
# Out:
#             Ride ID Rideable Type           Started At             Ended At  \
# 0  FB6B89D05B67EBED  classic_bike  2021-08-24 15:59:57  2021-08-24 16:42:07
# 1  E13DA3E30CEF8DFC  classic_bike  2021-08-18 13:12:01  2021-08-18 13:21:26
# 2  56617490AB8AE69C  classic_bike  2021-08-17 14:31:23  2021-08-17 14:35:34
# 3  CA908B271C7D6663  classic_bike  2021-08-11 10:00:12  2021-08-11 10:31:01
# 4  3E170CE1F4FE179D  classic_bike  2021-08-12 19:28:38  2021-08-12 19:48:50
#
#       Start Station Name  Start Station Id  \
# 0     Broadway & E 21 St           6098.10
# 1        E 13 St & 2 Ave           5820.08
# 2        E 95 St & 3 Ave           7365.13
# 3  Madison Ave & E 82 St           7188.13
# 4        E 74 St & 1 Ave           6953.08
#
#                                 End Station Name end_station_id  \
# 0  Central Park North & Adam Clayton Powell Blvd        7617.07
# 1                            Henry St & Grand St        5294.04
# ...

# %%
df9 = pd.read_csv('2021_data/202109-citibike-tripdata.csv')
df9.head()
# Out:
# /Users/rebeccamelo/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ride_id rideable_type           started_at             ended_at  \
# 0  22C33F42C6A0E28E  classic_bike  2021-09-01 10:26:45  2021-09-01 10:43:23
# 1  035F743147FCFCDE  classic_bike  2021-09-04 09:52:40  2021-09-04 10:09:19
# 2  9C43CF6A07DACBC6  classic_bike  2021-09-06 17:07:40  2021-09-06 17:34:44
# 3  253A1A5B20CC78EE  classic_bike  2021-09-28 16:53:43  2021-09-28 17:03:00
# 4  5E8F164D6798CEFA  classic_bike  2021-09-19 09:37:47  2021-09-19 09:53:42
#
#                 start_station_name  start_station_id         end_station_name  \
# 0      Central Park West & W 72 St           7141.07          E 51 St & 1 Ave
# ...

# %%
df9.rename(columns = {'ride_id': 'Ride ID', 'rideable_type': 'Rideable Type', 'started_at': 'Started At','ended_at': 'Ended At','start_station_name':'Start Station Name',
                      'start_station_id':'Start Station Id', 'end_station_name': 'End Station Name', 'end_station,id': 'End Station Id','start_lat':'Start Latitude',
                      'start_lng':'Start Longitude','end_lat':'End Latitude','end_lng':'End Longitude',
                      'member_casual':'Member Casual'}, inplace = True)
df9.head()
# Out:
#             Ride ID Rideable Type           Started At             Ended At  \
# 0  22C33F42C6A0E28E  classic_bike  2021-09-01 10:26:45  2021-09-01 10:43:23
# 1  035F743147FCFCDE  classic_bike  2021-09-04 09:52:40  2021-09-04 10:09:19
# 2  9C43CF6A07DACBC6  classic_bike  2021-09-06 17:07:40  2021-09-06 17:34:44
# 3  253A1A5B20CC78EE  classic_bike  2021-09-28 16:53:43  2021-09-28 17:03:00
# 4  5E8F164D6798CEFA  classic_bike  2021-09-19 09:37:47  2021-09-19 09:53:42
#
#                 Start Station Name  Start Station Id         End Station Name  \
# 0      Central Park West & W 72 St           7141.07          E 51 St & 1 Ave
# 1             William St & Pine St           5065.12                      NaN
# 2             Fulton St & Broadway           5175.08         Jay St & Tech Pl
# 3  West Drive & Prospect Park West           3651.04  Ocean Pkwy & Church Ave
# 4            Lorimer St & Broadway           4965.01         Jay St & Tech Pl
#
# ...

# %%
citibike_2021 = pd.concat([df4, df5, df6, df7, df8, df9])
citibike_2021
# Out:
#                   Ride ID Rideable Type           Started At  \
# 0        7099F9531C9DA16D   docked_bike  2021-04-28 17:27:24
# 1        EDC6F1B1A69A7863   docked_bike  2021-04-27 17:28:02
# 2        431A76830E10408A   docked_bike  2021-04-28 18:05:19
# 3        C00248A0ADC009FA   docked_bike  2021-04-20 21:35:47
# 4        BE78810D746EE516   docked_bike  2021-04-30 00:34:54
# ...                   ...           ...                  ...
# 3280216  8A1C8DB4249BF100  classic_bike  2021-09-26 16:00:45
# 3280217  C290EE73DF58AD79  classic_bike  2021-09-07 08:22:06
# 3280218  E42F8B93C4168658  classic_bike  2021-09-30 20:50:23
# 3280219  7221F0C58026A827  classic_bike  2021-09-08 19:06:24
# 3280220  689F3FAE372C013C  classic_bike  2021-09-27 07:58:57
#
#                     Ended At          Start Station Name Start Station Id  \
# 0        2021-04-28 17:34:31     DeKalb Ave & Hudson Ave          4513.06
# 1        2021-04-27 17:33:07          E 47 St & Park Ave          6584.12
# ...

# %%
citibike_2021['Started At'] = pd.to_datetime(citibike_2021['Started At'])
citibike_2021['Start Date'] = citibike_2021['Started At'].dt.date
citibike_2021['Start Time'] = citibike_2021['Started At'].dt.time

# %%
citibike_2021
# Out:
#                   Ride ID Rideable Type          Started At  \
# 0        7099F9531C9DA16D   docked_bike 2021-04-28 17:27:24
# 1        EDC6F1B1A69A7863   docked_bike 2021-04-27 17:28:02
# 2        431A76830E10408A   docked_bike 2021-04-28 18:05:19
# 3        C00248A0ADC009FA   docked_bike 2021-04-20 21:35:47
# 4        BE78810D746EE516   docked_bike 2021-04-30 00:34:54
# ...                   ...           ...                 ...
# 3280216  8A1C8DB4249BF100  classic_bike 2021-09-26 16:00:45
# 3280217  C290EE73DF58AD79  classic_bike 2021-09-07 08:22:06
# 3280218  E42F8B93C4168658  classic_bike 2021-09-30 20:50:23
# 3280219  7221F0C58026A827  classic_bike 2021-09-08 19:06:24
# 3280220  689F3FAE372C013C  classic_bike 2021-09-27 07:58:57
#
#                     Ended At          Start Station Name Start Station Id  \
# 0        2021-04-28 17:34:31     DeKalb Ave & Hudson Ave          4513.06
# 1        2021-04-27 17:33:07          E 47 St & Park Ave          6584.12
# ...

# %%
citibike_2021['Ended At'] = pd.to_datetime(citibike_2021['Ended At'])
citibike_2021['End Date'] = citibike_2021['Ended At'].dt.date
citibike_2021['End Time'] = citibike_2021['Ended At'].dt.time

# %%
citibike_2021
# Out:
#                   Ride ID Rideable Type          Started At  \
# 0        7099F9531C9DA16D   docked_bike 2021-04-28 17:27:24
# 1        EDC6F1B1A69A7863   docked_bike 2021-04-27 17:28:02
# 2        431A76830E10408A   docked_bike 2021-04-28 18:05:19
# 3        C00248A0ADC009FA   docked_bike 2021-04-20 21:35:47
# 4        BE78810D746EE516   docked_bike 2021-04-30 00:34:54
# ...                   ...           ...                 ...
# 3280216  8A1C8DB4249BF100  classic_bike 2021-09-26 16:00:45
# 3280217  C290EE73DF58AD79  classic_bike 2021-09-07 08:22:06
# 3280218  E42F8B93C4168658  classic_bike 2021-09-30 20:50:23
# 3280219  7221F0C58026A827  classic_bike 2021-09-08 19:06:24
# 3280220  689F3FAE372C013C  classic_bike 2021-09-27 07:58:57
#
#                    Ended At          Start Station Name Start Station Id  \
# 0       2021-04-28 17:34:31     DeKalb Ave & Hudson Ave          4513.06
# 1       2021-04-27 17:33:07          E 47 St & Park Ave          6584.12
# ...

# %%
citibike_2021.drop(columns=['Started At', 'Ended At'])
# Out:
#                   Ride ID Rideable Type          Start Station Name  \
# 0        7099F9531C9DA16D   docked_bike     DeKalb Ave & Hudson Ave
# 1        EDC6F1B1A69A7863   docked_bike          E 47 St & Park Ave
# 2        431A76830E10408A   docked_bike          E 47 St & Park Ave
# 3        C00248A0ADC009FA   docked_bike     Irving Ave & DeKalb Ave
# 4        BE78810D746EE516   docked_bike            3 Ave & E 112 St
# ...                   ...           ...                         ...
# 3280216  8A1C8DB4249BF100  classic_bike             8 Ave & W 31 St
# 3280217  C290EE73DF58AD79  classic_bike  S Portland Ave & Hanson Pl
# 3280218  E42F8B93C4168658  classic_bike      West End Ave & W 60 St
# 3280219  7221F0C58026A827  classic_bike      West End Ave & W 60 St
# 3280220  689F3FAE372C013C  classic_bike      West End Ave & W 60 St
#
#         Start Station Id          End Station Name end_station_id  \
# 0                4513.06       Douglass St & 4 Ave        4175.14
# ...

# %%
print(pd.unique(citibike_2021['Rideable Type']))
# Out:
# ['docked_bike' 'electric_bike' 'classic_bike']

# %%
citibike_2021_1 = citibike_2021.replace({'Rideable Type' : { 'docked_bike' : 'Docked Bike', 'docked_bike'  : 'Docked Bike', 'classic_bike' : 'Classic Bike' }})

# %%
citibike_2021_1
# Out:
#                   Ride ID Rideable Type          Started At  \
# 0        7099F9531C9DA16D   Docked Bike 2021-04-28 17:27:24
# 1        EDC6F1B1A69A7863   Docked Bike 2021-04-27 17:28:02
# 2        431A76830E10408A   Docked Bike 2021-04-28 18:05:19
# 3        C00248A0ADC009FA   Docked Bike 2021-04-20 21:35:47
# 4        BE78810D746EE516   Docked Bike 2021-04-30 00:34:54
# ...                   ...           ...                 ...
# 3280216  8A1C8DB4249BF100  Classic Bike 2021-09-26 16:00:45
# 3280217  C290EE73DF58AD79  Classic Bike 2021-09-07 08:22:06
# 3280218  E42F8B93C4168658  Classic Bike 2021-09-30 20:50:23
# 3280219  7221F0C58026A827  Classic Bike 2021-09-08 19:06:24
# 3280220  689F3FAE372C013C  Classic Bike 2021-09-27 07:58:57
#
#                    Ended At          Start Station Name Start Station Id  \
# 0       2021-04-28 17:34:31     DeKalb Ave & Hudson Ave          4513.06
# 1       2021-04-27 17:33:07          E 47 St & Park Ave          6584.12
# ...

# %%
citibike_2021_1.drop(columns=['Started At', 'Ended At'])
# Out:
#                   Ride ID Rideable Type          Start Station Name  \
# 0        7099F9531C9DA16D   Docked Bike     DeKalb Ave & Hudson Ave
# 1        EDC6F1B1A69A7863   Docked Bike          E 47 St & Park Ave
# 2        431A76830E10408A   Docked Bike          E 47 St & Park Ave
# 3        C00248A0ADC009FA   Docked Bike     Irving Ave & DeKalb Ave
# 4        BE78810D746EE516   Docked Bike            3 Ave & E 112 St
# ...                   ...           ...                         ...
# 3280216  8A1C8DB4249BF100  Classic Bike             8 Ave & W 31 St
# 3280217  C290EE73DF58AD79  Classic Bike  S Portland Ave & Hanson Pl
# 3280218  E42F8B93C4168658  Classic Bike      West End Ave & W 60 St
# 3280219  7221F0C58026A827  Classic Bike      West End Ave & W 60 St
# 3280220  689F3FAE372C013C  Classic Bike      West End Ave & W 60 St
#
#         Start Station Id          End Station Name end_station_id  \
# 0                4513.06       Douglass St & 4 Ave        4175.14
# ...

# %%
citibike_2021_1.to_csv('2021-citibike-data-AprToSept.csv')
